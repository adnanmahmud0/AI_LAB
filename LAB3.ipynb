# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/AI/PriceDataSet.csv')

# %%
print(df.to_string())
# Out:
#     weight  price
# 0        1     10
# 1        2     20
# 2        3     25
# 3        4     40
# 4        5     45
# 5        6     75
# 6        7     90
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.head()
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45

# %%
df.head(8)
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45
# 5       6     75
# 6       7     90
# 7       8    100

# %%
df.tail(4)
# Out:
#     weight  price
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.corr()
# Out:
#           weight     price
# weight  1.000000  0.989168
# price   0.989168  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   weight  15 non-null     int64
#  1   price   15 non-null     int64
# dtypes: int64(2)
# memory usage: 368.0 bytes

# %%
import matplotlib.pyplot as plt

df.plot(kind = 'scatter', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind = 'line', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind = 'bar', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind = 'hist', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind = 'pie', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind = 'scatter', x = 'weight', y = 'price')
plt.xlabel('Weight of potato')
plt.ylabel('Price of potato')
plt.show()

# %%
df["price"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/PriceDataSet-a - PriceDataSet.csv')

# %%
print(df.to_string())
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      NaN     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
new_df = df.dropna()
print(df)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      NaN     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/PriceDataSet-a - PriceDataSet.csv')
print(df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      NaN     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
new_df=df.fillna(130)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3    130.0     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10   130.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
x=df["weight"].mean()
print("Mean value is= ", x)
new_df=df.fillna(x)
print(new_df)
# Out:
# Mean value is=  8.076923076923077
#        weight  price
# 0    1.000000     10
# 1    2.000000     20
# 2    3.000000     25
# 3    8.076923     40
# 4    5.000000     45
# 5    6.000000     75
# 6    7.000000     90
# 7    8.000000    100
# 8    9.000000    115
# 9   10.000000    120
# 10   8.076923    130
# 11  12.000000    132
# 12  13.000000    140
# 13  14.000000    160
# 14  15.000000    165

# %%
x = df["weight"].mode()[0]
print(x)
# Out:
# 1.0

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# dtype: bool

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/PriceDataSet-dup.csv')
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# dtype: bool

# %%
new= df.drop_duplicates()
print(new.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# dtype: bool

# %%
df = pd.read_csv('/content/drive/MyDrive/AI/PriceDataSet.csv')
df.describe()
# Out:
#           weight       price
# count  15.000000   15.000000
# mean    8.000000   91.133333
# std     4.472136   52.283385
# min     1.000000   10.000000
# 25%     4.500000   42.500000
# 50%     8.000000  100.000000
# 75%    11.500000  131.000000
# max    15.000000  165.000000
